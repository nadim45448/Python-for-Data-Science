# %% [markdown]
# ### Namespaces
#
# A namespace is a space that holds names(identifiers).Programmatically speaking, namespaces are dictionary of identifiers(keys) and their objects(values)
#
# There are 4 types of namespaces:
# - Builtin Namespace
# - Global Namespace
# - Enclosing Namespace
# - Local Namespace

# %% [markdown]
# ### Scope and LEGB Rule
#
# A scope is a textual region of a Python program where a namespace is directly accessible.
#
# The interpreter searches for a name from the inside out, looking in the local, enclosing, global, and finally the built-in scope. If the interpreter doesn’t find the name in any of these locations, then Python raises a NameError exception.

# %%
# local and global
# global var
a = 2

def temp():
  # local var
  b = 3
  print(b)

temp()
print(a)
# Out:
# 3
# 2

# %%
# local and global -> same name
a = 2

def temp():
  # local var
  a = 3
  print(a)

temp()
print(a)
# Out:
# 3
# 2

# %%
# local and global -> local does not have but global has
a = 2

def temp():
  # local var
  print(a)

temp()
print(a)
# Out:
# 2
# 2

# %%
# local and global -> editing global inside local is not allowed
a = 2

def temp():
  # local var
  a += 1
  print(a)

temp()
print(a)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-5-3615709408.py in <cell line: 0>()
#       7   print(a)
#       8
# ----> 9 temp()
#      10 print(a)
#
# /tmp/ipython-input-5-3615709408.py in temp()
#       4 def temp():
#       5   # local var
# ----> 6   a += 1
#       7   print(a)
#       8
#
# UnboundLocalError: cannot access local variable 'a' where it is not associated with a value

# %%
# using global keyword, editing global var inside local scope is allowed
a = 2

def temp():
  # local var
  global a
  a += 1
  print(a)

temp()
print(a)
# Out:
# 3
# 3

# %%
# local and global -> global created inside local
def temp():
  # local var
  global a
  a = 1
  print(a)

temp()
print(a)
# Out:
# 1
# 1

# %%
# local and global -> function parameter is local
def temp(z):
  # local var
  print(z)

a = 5
temp(5)
print(a)
print(z)
# Out:
# 5
# 5
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9-736710718.py in <cell line: 0>()
#       7 temp(5)
#       8 print(a)
# ----> 9 print(z)
#
# NameError: name 'z' is not defined

# %%
# built-in scope
import builtins
print(dir(builtins))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %%
# renaming built-ins
L = [1,2,3]
print(max(L))
def max():
  print('hello')

print(max(L))
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-375767152.py in <cell line: 0>()
#       5   print('hello')
#       6
# ----> 7 print(max(L))
#
# TypeError: max() takes 0 positional arguments but 1 was given

# %%
# Enclosing scope
def outer():
  def inner():
    print(a)
  inner()
  print('outer function')


outer()
print('main program')
# Out:
# 5
# outer function
# main program

# %%
# nonlocal keyword
def outer():
  a = 1
  def inner():
    nonlocal a
    a += 1
    print('inner',a)
  inner()
  print('outer',a)


outer()
print('main program')
# Out:
# inner 2
# outer 2
# main program

# %% [markdown]
# ### Decorators
#
# A decorator in python is a function that receives another function as input and adds some functionality(decoration) to and it and returns it.
#
# This can happen only because python functions are 1st class citizens.
#
# There are 2 types of decorators available in python
# - `Built in decorators` like `@staticmethod`, `@classmethod`, `@abstractmethod` and `@property` etc
# - `User defined decorators` that we programmers can create according to our needs

# %%
# Python are 1st class function(store, delete......)
def func():
    print("HI")

a=func()
print(a)

del func
# Out:
# HI
# None

# %%
# Python are 1st class function

def modify(func,num):
  return func(num)
# modify()->decorator

def square(num):
  return num**2
# square()->input

modify(square,2)
# Out:
# 4

# %%
def my_decorator(func):
  def wrapper():
    print('********************')
    func()
    print('********************')
  return wrapper


def hello():
  print('hello')

def display():
  print('nadim')

a = my_decorator(hello)
a()

b= my_decorator(display)
b()
# Out:
# ********************
# hello
# ********************
# ********************
# nadim
# ********************

# %%
# more functions

# %%
# how this works -> closure?

# %%
# python tutor

# %%
# Better syntax?
# simple example

def my_decorator(func):
  def wrapper():
    print('********************')
    func()
    print('********************')
  return wrapper


@my_decorator
def hello():
  print('hello')

hello()
# Out:
# ********************
# hello
# ********************

# %%
# anything meaningful
import time
def timer(func):
  def wrapper():
    start = time.time()
    func()
    print('time taken by', func.__name__,time.time()-start,'secs')
  return wrapper

# func.__name__ = actual name of function

@timer
def hello():
  print('hello wolrd')
  time.sleep(2)

hello()
# Out:
# hello wolrd
# time taken by hello 2.0016708374023438 secs

# %%
# Decorator with arguments
import time
def timer(func):
  def wrapper():
    start = time.time()
    func()
    print('time taken by', func.__name__,time.time()-start,'secs')
  return wrapper

# func.__name__ = actual name of function


@timer
def square(num):
  time.sleep(1)
  print(num**2)

square(2)

# @timer
# def power(a,b):
#   print(a**b)

# power(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      15   time.sleep(1)
#      16   print(num**2)
# ---> 18 square(2)
#      20 # @timer
#      21 # def power(a,b):
#      22 #   print(a**b)
#      23
#      24 # power(2,3)
#
# TypeError: timer.<locals>.wrapper() takes 0 positional arguments but 1 was given

# %%
# One last example -> decorators with arguments
# anything meaningful
import time
def timer(func):
  def wrapper(*args):
    start = time.time()
    func(*args)
    print('time taken by', func.__name__,time.time()-start,'secs')
  return wrapper

# func.__name__ = actual name of function

@timer
def hello():
  print('hello wolrd')
  time.sleep(2)

# hello()


@timer
def square(num):
  time.sleep(1)
  print(num**2)

# square(2)

@timer
def power(a,b):
  print(a**b)

power(2,3)
# Out:
# 8
# time taken by power 0.0 secs

# %%
# A big problem
# A big problem:
def square (a):
  print(a**2)

# square(2)
square(haha)

# amra emon ekta decorator banate chai jeta data type check korbe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       4   print(a**2)
#       6 # square(2)
# ----> 7 square(haha)
#
# NameError: name 'haha' is not defined

# %%
# @checkdt(int)
def square(num):
  print(num**2)
# Jokhon amra square function k call korbo, num er data type check korbe. jodi data type int hoy tahole execute korbe, nahole korbena

# %%
def sanity_check(data_type): # receive data type (int, float, str)
  def outer_wrapper(func): # outer wrapper receive function: square, greet
    def inner_wrapper(*args):
      if(type(*args) == data_type):
        func(*args)
      else:
        raise TypeError('data type mismatch')
    return inner_wrapper
  return outer_wrapper



@sanity_check(int)
def square(num):
  print(num**2)

@sanity_check(str)
def greet(name):
  print('hello',name)

square(2)
greet('nadim')
# Out:
# 4
# hello nadim
