# %%
import pandas as pd

# %% [markdown]
# ### `Q-1`: Write a program to create an empty series

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %% [markdown]
# ### `Q-2:` Write a Pandas program to add, subtract, multiple and divide two Pandas Series.

# %%
a= pd.Series([2, 4, 6, 8, 10])
b= pd.Series([1, 3, 5, 7, 10])

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    20
# dtype: int64
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# dtype: int64
# 0      2
# 1     12
# 2     30
# 3     56
# 4    100
# dtype: int64
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.000000
# dtype: float64

# %% [markdown]
# ### `Q-3` Write a Pandas program to compare the elements of the two Pandas Series.
# Sample Series: [2, 4, 6, 8, 10], [1, 3, 5, 7, 10]

# %%
a = pd.Series([2, 4, 6, 8, 10])
b = pd.Series([1, 3, 5, 7, 10])

print(a==b)
print(a<b)
print(a>b)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# ### `Q-5.`Write a function to change the data type of given a column or a Series. Function takes series and data type as input, returns the converted series.
# ```
# series = pd.Series([1,2,'Python', 2.0, True, 100])
# change to float type data
# ```
# Note: Read about pd.to_numeric()

# %%
series = pd.Series([1,2,'Python', 2.0, True, 100])

# %%
def change_dtype(series):
  return pd.to_numeric(series, errors='coerce')

# %%
change_dtype(series)
# Out:
# 0      1.0
# 1      2.0
# 2      NaN
# 3      2.0
# 4      1.0
# 5    100.0
# dtype: float64

# %%
data = pd.read_csv("/content/drive/MyDrive/Python-for-Data-Science/05_Pandas/dataset/batsman_runs_series.csv")

# %%
data.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
data.tail()
# Out:
#             batter  batsman_run
# 600     Yash Dayal            0
# 601  Yashpal Singh           47
# 602    Younis Khan            3
# 603   Yuvraj Singh         2754
# 604         Z Khan          117

# %% [markdown]
# ### `Q-6` Find top 10 most run getter from the series.

# %%
data.sort_values('batsman_run', ascending=False).head(10)
# Out:
#              batter  batsman_run
# 569         V Kohli         6634
# 462        S Dhawan         6244
# 130       DA Warner         5883
# 430       RG Sharma         5881
# 493        SK Raina         5536
# 27   AB de Villiers         5181
# 108        CH Gayle         4997
# 339        MS Dhoni         4978
# 452      RV Uthappa         4954
# 256      KD Karthik         4377

# %% [markdown]
# ### `Q-7` No of players having runs above 3000

# %%
data[data['batsman_run']>3000].shape[0]
# Out:
# 20

# %% [markdown]
# ### `Q-8` No of players having runs above mean value?

# %%
data[data['batsman_run'] > data['batsman_run'].mean()].shape[0]
# Out:
# 128

# %% [markdown]
# ### `Q-9`
#     i. Read `items.csv` making `item_name` as index.
#     ii. Show no of nan values
#     ii. Item price is given in $, so convert it to rupees without currency symbol.
#     iii. Make data type of newly made series as float.
#     iv. Fill nan with mean of the series

# %%
#1
item = pd.read_csv("/content/drive/MyDrive/Python-for-Data-Science/05_Pandas/dataset/items.csv", index_col='item_name')

# %%
item = item.squeeze()
item
# Out:
# item_name
# Chips and Fresh Tomato Salsa              $2.39
# Izze                                      $3.39
# Nantucket Nectar                          $3.39
# Chips and Tomatillo-Green Chili Salsa     $2.39
# Chicken Bowl                             $16.98
#                                           ...
# Steak Burrito                            $11.75
# Steak Burrito                            $11.75
# Chicken Salad Bowl                       $11.25
# Chicken Salad Bowl                        $8.75
# Chicken Salad Bowl                        $8.75
# Name: item_price, Length: 4622, dtype: object

# %%
item.tail()
# Out:
# item_name
# Steak Burrito         $11.75
# Steak Burrito         $11.75
# Chicken Salad Bowl    $11.25
# Chicken Salad Bowl     $8.75
# Chicken Salad Bowl     $8.75
# Name: item_price, dtype: object

# %%
# ii. Show no of nan values
item.isna().sum()
# Out:
# np.int64(50)

# %%
# !git clone https://github.com
# Out:
# Cloning into 'github.com'...
# fatal: repository 'https://github.com/' not found
