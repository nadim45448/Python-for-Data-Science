# %% [markdown]
# ### What is Pandas
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.

# %% [markdown]
# ### Pandas Series
#
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type.

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd
# student table:
# column: name, id, cgpa, major (each column is series)

# %% [markdown]
# ### Series from lists

# %%
# strings
country=['Bangladesh', 'USA', 'Pakistan', 'India']
pd.Series(country)
# Out:
# 0    Bangladesh
# 1           USA
# 2      Pakistan
# 3         India
# dtype: object

# %%
# integers
marks = [165, 47, 93, 52]
pd.Series(marks)
# Out:
# 0    165
# 1     47
# 2     93
# 3     52
# dtype: int64

# %%
marks = [165, 47, 93, 52]

subjects = ['physics', 'chemistry', 'biology', 'math']
pd.Series(marks,index=subjects, name='Nadim er marks')
# Out:
# physics      165
# chemistry     47
# biology       93
# math          52
# Name: Nadim er marks, dtype: int64

# %%
marks = [165, 47, 93, 52]
marks = [165, 47, 93, 52]

subjects = ['physics', 'chemistry', 'biology', 'math']
marks = pd.Series(marks,index=subjects, name='Nadim er marks')
marks
# Out:
# physics      165
# chemistry     47
# biology       93
# math          52
# Name: Nadim er marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'math': 70,
    'physics': 80,
    'chemistry':75
}
marks = pd.Series(marks, name='nadim er marks')
marks
# Out:
# math         70
# physics      80
# chemistry    75
# Name: nadim er marks, dtype: int64

# %% [markdown]
# ### Series Attributes

# %%
# size : total no of row
marks.size
# Out:
# 3

# %%
# dtype
marks.dtype
# Out:
# dtype('int64')

# %%
# nmae
marks.name
# Out:
# 'nadim er marks'

# %%
# is_unique
marks.is_unique
# Out:
# True

# %%
# index
marks.index
# Out:
# Index(['math', 'physics', 'chemistry'], dtype='object')

# %%
# value
marks.values
# Out:
# array([70, 80, 75])

# %% [markdown]
# ### Series using read_csv

# %%
# read_csv() : data frame
# read_csv(squeeze= true) : series

# %%
import pandas as pd

# %%
# with one column
subs = pd.read_csv('/content/drive/MyDrive/Python-for-Data-Science/05_Pandas/dataset/subs.csv')
subs = subs.squeeze("columns")
print(subs)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 column
vk= pd.read_csv('/content/drive/MyDrive/Python-for-Data-Science/05_Pandas/dataset/kohli_ipl.csv', index_col='match_no')

# %%
vk = vk.squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/drive/MyDrive/Python-for-Data-Science/05_Pandas/dataset/bollywood.csv', index_col="movie")
movies = movies.squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series methods

# %%
# head and tail
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(2)
# Out:
# match_no
# 1     1
# 2    23
# Name: runs, dtype: int64

# %%
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
movies.tail(3)
# Out:
# movie
# Saathiya (film)         Vivek Oberoi
# Company (film)            Ajay Devgn
# Awara Paagal Deewana    Akshay Kumar
# Name: lead, dtype: object

# %%
# sample : randomly select
subs.sample()
# Out:
# 72    92
# Name: Subscribers gained, dtype: int64

# %%
subs.sample(3)
# Out:
# 111     78
# 173    114
# 216    127
# Name: Subscribers gained, dtype: int64

# %%
# value counts : how many times a data is present

movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
# sort values
vk.sort_values(ascending=False)
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 120    100
# 164    100
#       ...
# 93       0
# 130      0
# 206      0
# 207      0
# 211      0
# Name: runs, Length: 215, dtype: int64

# %%
# sort values
vk.sort_values(ascending=False).head(1)
# Out:
# match_no
# 128    113
# Name: runs, dtype: int64

# %%
# sort values
vk.sort_values(ascending=False).head(1).values
# return numpy array
# Out:
# array([113])

# %%
vk.sort_values(ascending = False).head(1).values[0]
# fatch highest score
# Out:
# np.int64(113)

# %%
vk.sort_values(ascending=False, inplace=True)
# when we use inplace = True, it parmanently change the value

# %%
vk.head()
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# sort_index -> inplace -> movies
movies.sort_index(ascending=False,inplace=True)

# %% [markdown]
# ### Series Maths Methods

# %%
# count: return total no of rows
# vk
vk.count()
# Out:
# np.int64(215)

# %%
# sum -> product
subs.sum()
# Out:
# np.int64(49510)

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: object
# 62.67502303725269
# 688.0024777222344

# %%
# min/max
subs.max()
# Out:
# 396

# %%
# describe
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# 5    57
# 6    58
# 7    79
# 8     9
# dtype: int64

# %%
# positive indexing
x[1]
# Out:
# np.int64(13)

# %%
# Negative indexing: do not work for int data type, work for string data type
x[-1]
# vk[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-599712904.py in <cell line: 0>()
#       1 # Negative indexing
# ----> 2 x[-1]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
# Negative indexing work for string data type
# print(movies)
print(movies[-1])
# Out:
# Akshay Kumar
# /tmp/ipython-input-3916250543.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(movies[-1])

# %%
# slicing
vk[3:7]
# Out:
# match_no
# 4    12
# 5     1
# 6     9
# 7    34
# Name: runs, dtype: int64

# %%
# negative slicing
vk[-5:]
# though negative indexing is not work for int data type, but negative slicing work
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[::2]
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
# fancy indexing
vk[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels -> fancy indexing
movies['2 States (2014 film)']
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# ### Editing Series

# %%
# using indexing
marks_series=[10,20,30,40]
marks_series= pd.Series(marks_series)
marks_series[1] = 100
marks_series
# Out:
# 0     10
# 1    100
# 2     30
# 3     40
# dtype: int64

# %%
# what if an index does not exist
marks_series['evs'] = 100

# %%
marks_series
# Out:
# 0       10
# 1      100
# 2       30
# 3       40
# evs    100
# dtype: int64

# %%
# slicing
marks_series[2:4] = [100,100]
marks_series
# Out:
# 0       10
# 1      100
# 2      100
# 3      100
# evs    100
# dtype: int64

# %%
# fancy indexing
subs[[0,3,4]] = [0,0,0]
subs
# Out:
# 0        0
# 1       57
# 2       40
# 3        0
# 4        0
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# using index label
movies['2 States (2014 film)'] = 'Alia Bhatt'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min
print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ...

# %%
# type conversion
list(marks_series)
# Out:
# [10, 100, 100, 100, 100]

# %%
dict(marks_series)
# Out:
# {0: np.int64(10),
#  1: np.int64(100),
#  2: np.int64(100),
#  3: np.int64(100),
#  'evs': np.int64(100)}

# %%
# membership operator

'2 States (2014 film)' in movies
# Out:
# True

# %%
'Alia Bhatt' in movies.values
# Out:
# True

# %%
# looping
for i in movies.index:
  print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic Operators(Broadcasting)
100 + marks_series
# Out:
# 0      110
# 1      200
# 2      200
# 3      200
# evs    200
# dtype: int64

# %%
# Relational Operators

vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk >= 50].size
# Out:
# 50

# %%
# find number of ducks
vk[vk == 0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Some Important Series Methods

# %%
# astype
# between
# clip
# drop_duplicates, duplicated
# isnull
# dropna
# fillna
# isin
# apply: custom logic
# copy

# %%
# astype : change data type
import sys
sys.getsizeof(vk)
# Out:
# 3472

# %%
# vk.astype('int16')
sys.getsizeof(vk.astype('int16'))
# Out:
# 2182

# %%
# between :return true, false (series)
vk.between(51,99)
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
vk[vk.between(51,99)]
# Out:
# match_no
# 34     58
# 41     71
# 44     56
# 45     67
# 52     70
# 57     57
# 68     73
# 71     51
# 73     58
# 74     65
# 80     57
# 81     93
# 82     99
# 85     56
# 97     67
# 99     73
# 103    51
# 104    62
# 110    82
# 116    75
# 117    79
# 119    80
# 122    52
# 127    75
# 129    54
# 131    54
# 132    62
# 134    64
# 137    55
# 141    58
# 144    57
# 145    92
# 148    68
# 152    70
# 160    84
# 162    67
# 175    72
# 178    90
# 188    72
# 197    51
# 198    53
# 209    58
# 213    73
# Name: runs, dtype: int64

# %%
vk[vk.between(51,99)].size
# Out:
# 43

# %%
# clip
vk.clip(100,200)
# 100 er nicher value gulo 100 diye replace hobe, 200 er uporer value gulo 200 diye replace hobe
# Out:
# match_no
# 1      100
# 2      100
# 3      100
# 4      100
# 5      100
#       ...
# 211    100
# 212    100
# 213    100
# 214    100
# 215    100
# Name: runs, Length: 215, dtype: int64

# %%
# drop_duplicates
a= pd.Series([1,1,1,1,4,8,7,6,7,9,10,9,15])

a
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      4
# 5      8
# 6      7
# 7      6
# 8      7
# 9      9
# 10    10
# 11     9
# 12    15
# dtype: int64

# %%
# a.drop_duplicates()
a.drop_duplicates(keep='last')
# Out:
# 3      1
# 4      4
# 5      8
# 7      6
# 8      7
# 10    10
# 11     9
# 12    15
# dtype: int64

# %%
# drop_duplicates
a= pd.Series([1,1,1,1,4,8,7,6,7,9,10,9,15])
a
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      4
# 5      8
# 6      7
# 7      6
# 8      7
# 9      9
# 10    10
# 11     9
# 12    15
# dtype: int64

# %%
a.duplicated()
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# 12    False
# dtype: bool

# %%
a.duplicated().sum()
# there are total 5 duplicated values
# Out:
# np.int64(5)

# %%
# isnull
temp = pd.Series([1,4,np.nan,8,5,np.nan,np.nan,7,np.nan])

# %%
print(temp.size) #return total with nan value
print(temp.count()) #return without nan
# Out:
# 9
# 5

# %%
temp.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6     True
# 7    False
# 8     True
# dtype: bool

# %%
temp.isnull().sum()
# Out:
# np.int64(4)

# %%
# dropna
temp.dropna()
# drop all missing values
# Out:
# 0    1.0
# 1    4.0
# 3    8.0
# 4    5.0
# 7    7.0
# dtype: float64

# %%
# fillna : replace missing values with 0 (can replace with anything)
temp.fillna(0)
# temp.fillna(temp.mean())
# Out:
# 0    1.0
# 1    4.0
# 2    0.0
# 3    8.0
# 4    5.0
# 5    0.0
# 6    0.0
# 7    7.0
# 8    0.0
# dtype: float64

# %%
# isin
vk[(vk == 49) | (vk == 99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
# apply
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: object

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
# copy
vk
# Out:
# match_no
# 1      15
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head()
# vk.head() = view of original data, if we change anything on new, vk will also change

# %%
new[1] = 15

# %%
new = vk.head().copy()
# copy of of original data, id change anything on new, original data won't change

# %%
new[1] = 100

# %%
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64
