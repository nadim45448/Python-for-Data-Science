# %% [markdown]
# Strings are sequence of Characters
#
# In Python specifically, strings are a sequence of Unicode Characters
#
# - Creating Strings
# - Accessing Strings
# - Adding Chars to Strings
# * Editing Strings
# * Deleting Strings
# - Operations on Strings
# - String Functions

# %% [markdown]
# # Creating String

# %%
s = 'hello'
s = "hello"
# multiline string
s = '''hello'''
s = """hello"""
s = str(s)
print(s)
# Out:
# hello

# %%
'it's raining outside'
# Out:
#   File "/tmp/ipython-input-2-1304262139.py", line 1
#     'it's raining outside'
#                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"it's raining "
# Out:
# "it's raining "

# %% [markdown]
# # Accessing substring from a string

# %%
# Positive indexing
s = 'hello world'
print(s[1])
# Out:
# e

# %%
# Negative indexing
s = 'hello world'
s[-1]
# Out:
# 'd'

# %%
# slicing
s = 'hello world'
print(s[0:5])
print(s[1:])
print(s[:5])
print(s[0:8:2])

print(s[-1:-6])
# Out:
# hello
# ello world
# hello
# hlow

# %%
# reverse string
print(s[::-1])
# Out:
# dlrow olleh

# %%
s = 'hello world'
print(s[-1:-6:-1])
# Out:
# dlrow

# %% [markdown]
# # Editing and Deleting in Strings

# %%
s = 'hello world'
s[0] = 'H'

# Python strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-16-2237226474.py in <cell line: 0>()
#       1 s = 'hello world'
# ----> 2 s[0] = 'H'
#       3
#       4 # Python strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'hello world'
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-17-2968721042.py in <cell line: 0>()
#       1 s = 'hello world'
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined

# %%
s = 'hello world'
del s[-1:-5:2]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-18-266792670.py in <cell line: 0>()
#       1 s = 'hello world'
# ----> 2 del s[-1:-5:2]
#       3 print(s)
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# # Operations on Strings
# - Arithmetic Operations
# - Relational Operations
# - Logical Operations
# - Loops on Strings
# - Membership Operations

# %%
print('Dhaka' + ' ' + 'Noakhali')
# Out:
# Dhaka Noakhali

# %%
print('Dhaka'*5)
# Out:
# DhakaDhakaDhakaDhakaDhaka

# %%
print("*"*50)
# Out:
# **************************************************

# %%
'dhaka' != 'dhaka'
# Out:
# False

# %%
'noakhali' > 'dhaka'
# lexiographically [Dictionary]
# Out:
# True

# %%
'Dhaka' > 'dhaka'
# Out:
# False

# %%
# the last value if all are truthy
'hello' and 'world'
# Out:
# 'world'

# %%
'hello' or 'world'
# Out:
# 'hello'

# %%
# the first falsy value it finds
'' and 'world'
# Out:
# ''

# %%
'' or 'world'
# Out:
# 'world'

# %%
not 'hello'
# Out:
# False

# %%
for i in 'hello':
  print(i)
# Out:
# h
# e
# l
# l
# o

# %%
'D' in 'delhi'
# Out:
# False

# %% [markdown]
# # Common Functions
# - len
# - max
# - min
# - sorted

# %%
len('hello world')
# Out:
# 11

# %%
max('hello world')
# Out:
# 'w'

# %%
min('hello world')
# Out:
# ' '

# %%
sorted('hello world',reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %% [markdown]
# # Capitalize/Title/Upper/Lower/Swapcase

# %%
s = 'hello world'
print(s.capitalize())
print(s)
# Out:
# Hello world
# hello world

# %%
s.title()
# Out:
# 'Hello World'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
'Hello Wolrd'.lower()
# Out:
# 'hello wolrd'

# %%
'HeLlO WorLD'.swapcase()
# Out:
# 'hElLo wORld'

# %% [markdown]
# # Count/Find/Index

# %%
'my name is nadim'.count('i')
# Out:
# 2

# %%
'my name is nadim'.find('x')
# Out:
# -1

# %%
'my name is nadim'.index('m')
# Out:
# 0

# %% [markdown]
# # endswith/startswith

# %%
'my name is nadim'.endswith('sho')
# Out:
# False

# %%
'my name is nadim'.startswith('1my')
# Out:
# False

# %% [markdown]
# # format

# %%
name = 'nadim'
gender = 'male'

'Hi my name is {1} and I am a {0}'.format(gender,name)
# Out:
# 'Hi my name is nadim and I am a male'

# %% [markdown]
# # isalnum/ isalpha/ isdigit/ isidentifier

# %%
'nadim1234'.isalnum()
# Out:
# True

# %%
'nadim'.isalpha()
# Out:
# True

# %%
'123abc'.isdigit()
# Out:
# False

# %%
'first-name'.isidentifier()
# Out:
# False

# %% [markdown]
# # Split/Join

# %%
'hi my name is nadim'.split()
# Out:
# ['hi', 'my', 'name', 'is', 'nadim']

# %%
"-".join(['hi', 'my', 'name', 'is', 'nitish'])
# Out:
# 'hi-my-name-is-nitish'

# %% [markdown]
# # Replace

# %%
'hi my name is nadim'.replace('nadim','hossain')
# Out:
# 'hi my name is hossain'

# %% [markdown]
# # Strip

# %%
'nadim                           '.strip()
# Out:
# 'nadim'

# %% [markdown]
# # Example Programs

# %%
# Find the length of a given string without using the len() function
s = input('enter the string: ')
count = 0
for i in s:
  count+=1;
print("length: ", count)
# Out:
# enter the string: kire bhai
# length:  9

# %%
# Extract username from a given email.
# Eg if the email is nadim1234@gmail.com
# then the username should be nadim1234

s = input('enter the email: ')
pos = s.index('@')
print(s[0:pos])
# Out:
# enter the email: nadim1234@gmail.com
# nadim1234

# %%
# Count the frequency of a particular character in a provided string.
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input('enter the string: ')
find = input('what would like to search for: ')

count = 0
for i in s:
  if i == find:
    count+=1

print('frequency: ', count)
# Out:
# enter the string: nadim bin hossain
# what would like to search for: n
# frequency:  3

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string')
term = input('what would like to remove')
result = ''
for i in s:
  if i!=term:
    result = result + i
print(result)

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s = input('enter the string')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome')
    break

if flag:
  print('Palindrome')

# %%
# Write a program to count the number of words in a string without split()

s = input('enter the string')
L = []
temp = ''
for i in s:

  if i != ' ':
    temp = temp + i
  else:
    L.append(temp)
    temp = ''

L.append(temp)
print(L)
# Out:
# enter the stringnadim bin hossain
# ['nadim', 'bin', 'hossain']

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
